# %% [markdown]
# #Projeto #3 - Aplicação da Regressão Linear
# >Análise de dados do GapMinder e aplicação do método de regressão linear durante o processo.
#
# >Dado analisado: CO2 (CO2 emissions)

# %% [markdown]
# ##Etapa #1 - PARTE TEÓRICA
# De maneira bastante simplificada, a técnica estatística chamada de regressão nada mais é do que uma
# ferramenta que costuma ser bastante empregada quando se objetiva modelar o efeito que algumas
# variáveis exercem nas outras (no geral, uma variável em função de outras). Basicamente, este estudo
# consiste na construção e análise de uma relação matemática entre as tais variáveis de interesse.
# Na terminologia de regressão, a variável que se deseja estudar (efeito) é chamada de variável
# dependente ou resposta. Já as variáveis que são usadas para explicar a variável dependente são
# chamadas de regressores, de variáveis independentes ou de variáveis explicativas (causas). Dessa forma,
# a análise de regressão consiste em estudar como alterações nas variáveis explicativas influenciam o
# comportamento médio da variável resposta.
# O tipo mais simples de análise de regressão, chamado de regressão linear simples, envolve uma variável
# explicativa (comumente chamada de X) e uma variável resposta (comumente chamada de Y). Aqui, vale
# ressaltar que o termo regressão linear significa regressão linear nos parâmetros.

# %% [markdown]
# a) Obtenha os estimadores de
# $\beta_1$
# e
# $\beta_1$
# a partir do Método dos Mínimos Quadrados, cujo objetivo
# é encontrar a reta que passa mais próxima ao mesmo tempo de todos os pontos. Neste caso,
# encontre os estimadores
# $\beta_0$^
# e
# $\beta_1$^
# que minimizam a soma dos erros ao quadrado:
# $y_i = \beta_0 + \beta_1 x_i + e_i \,\!$
#
# $S(\beta_0,\beta_1) = \sum_{i=1}^n \left( y_i - \beta_0 - \beta_1 x_i \right) ^2$
#
# Aplicando a regra da cadeia para a derivada parcial sobre os eixos:
#
# $\begin{align}
# {\partial S \over \partial \beta_0} & = {\partial S \over \partial x}*{\partial x \over \partial \beta_0}\\
# {\partial S \over \partial x} & =  2\sum_{i=1}^n \left( y_i - \beta_0 - \beta_1 x_i \right)\\
# {\partial x \over \partial \beta_0} & = -1\\
# {\partial S \over \partial \beta_0} & =  2\sum_{i=1}^n \left( y_i - \beta_0 - \beta_1 x_i \right) * -1 = 0 \\
# {\partial S \over \partial \beta_0} & = -2 \sum_{i=1}^n \left( y_i - \beta_0 - \beta_1 x_i \right) = 0 \\
# {\partial S \over \partial \beta_1} & = -2 \sum_{i=1}^n x_i \left( y_i - \beta_0 - \beta_1 x_i \right) = 0 \\
# \end{align}$
#
# Dividindo por $2n \,\!$ e distrbuindo
#
# $\begin{align}
# & \frac{-2 \sum_{i=1}^n y_i} {2n} + \frac{2 \sum_{i=1}^n \beta_0} {2n} + \frac{2 \sum_{i=1}^n \beta_1 x_i} {2n} = \frac{0} {2n} \\
# & \frac{-\sum_{i=1}^n y_i} {n} + \frac{\sum_{i=1}^n \beta_0} {n} + \frac{\beta_1 \sum_{i=1}^n x_i} {n} = 0 \\
# & -\bar{y} + \beta_0 + \beta_1 \bar{x} = 0 \\
# & \beta_0 = \bar{y} - \beta_1 \bar{x}
# \end{align}$
#
# Em que $\bar{y}$ é a Média Amostral de $y \,\!$ e $\bar{x}$ é a Média Amostral de $x \,\!$
#
# $\begin{align}
# & -2 \sum_{i=1}^n x_i \left(y_i - \bar{y} + \beta_1 \bar{x} - \beta1 x_i \right) = 0 \\
# & \sum_{i=1}^n \left[ x_i \left( y_i - \bar{y} \right) + x_i \beta1 \left( \bar{x} - x_i \right) \right] = 0 \\
# & \sum_{i=1}^n x_i \left( y_i - \bar{y} \right) + \beta_1 \sum_{i=1}^n x_i \left( \bar{x} - x_i \right) = 0 \\
# & \beta_1 = \frac{\sum_{i=1}^n \left( x_i - \bar{x} \right) \left( y_i - \bar{y} \right)} {\sum_{i=1}^n \left( x_i - \bar{x} \right)^2}
# \end{align}$
#
# Outro tipo de analise de regressão é a regressão multipla, na qual envolve duas ou mais variaveis explicativas influenciando na variavel resposta. Assim a equacao da reta se altera ligeiramente:
#
#  **EQUACAO DA RETA**
# Nesse projeto analisaremos as combinações possíveis entre 3 variaveis explicativas que podem influenciar na emissao de CO2 no mundo.
#
# b) Descreva as suposições feitas sobre os erros em termos de distribuição, valor esperado e
# variância e responda como pode ser checada, na prática, a adequação dessas suposições.
#
# https://github.com/MatheusDMD/data-science-student/blob/master/Projeto%203/Entrega%202%20%20-%20Exerc%C3%ADcio%201/IMG-20151125-WA0003.jpg
#
# c) Como ficam os testes de hipóteses na regressão simples e o que a rejeição ou não da particular
# hipótese nula H0 significa no caso?
#
# https://github.com/MatheusDMD/data-science-student/blob/master/Projeto%203/Entrega%202%20%20-%20Exerc%C3%ADcio%201/IMG-20151125-WA0002.jpg
#
# d) É possível fazer uma regressão com mais do que uma variável explicativa – regressão múltipla?
# Se sim, o que muda ou não muda quando comparada com a regressão simples descrita na
# equação (1).
#
# https://github.com/MatheusDMD/data-science-student/blob/master/Projeto%203/Entrega%202%20%20-%20Exerc%C3%ADcio%201/IMG-20151125-WA0004.jpg
#
# *****

# %% [markdown]
# ##ETAPA #2 - PARTE PRÁTICA
#
# ###Objetivo
# Ao Analisar os [gráficos](https://github.com/MatheusDMD/data-science-student/blob/master/Projeto%203/Projeto%20%233%20entrega%20%231.docx "Link para o Github") provenientes da ferramenta [Gapminder](http://www.gapminder.org/ "Ferramenta Gapminder") pudemos observar algumas relações entre nossa variável dependente (**CO2_2007** - Emissão de CO2) com algumas variáveis explicativas (**VEHICLE_2007**- Número de automoveis/pessoas; **ENERGY_2007**-Produção total de energia elétrica/pessoas; **ENERGY_SUPPLY_2010**-Suprimento total de energia elétrica/população). Após uma análise visual dos dados, recolhemos essas variáveis e com o objetivo de analisar a influência de cada uma delas e delas combinadas sobre o modelo e encontrar o modelo de regressão linear que melhor se adeque a variável dependente.
#
# **Para fins do modelo, assumimos algumas condições que serão validadas durante a analise:**
#
# - Média dos erros é zero
# - Distribuição do erro tem a mesma variância ao longo dos xi (isso é conhecido como homocedasticidade)
# - Os erros não sejam correlacionados entre si
# - Os erros têm distribuição normal

# %%
# %matplotlib inline
import os
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import numpy.random as rnd
from scipy.stats import ttest_ind
import math
import random
import statsmodels.api as sm

print("Esperamos trabalhar no diretório")
print(os.getcwd())
# Out:
# Esperamos trabalhar no diretório
# C:\Users\mathe_000\Documents\GitHub\data-science-student\Projeto 3

# %%
ENERGY_SUPPLY = pd.read_excel('Indicator_Energysupply per capita.xlsx')
ENERGY = pd.read_excel('energy use per person.xlsx')
VEHICLES = pd.read_excel('indicator Motor vehicles per 1000 population 20100824.xlsx')
CO2 = pd.read_excel('indicator CDIAC carbon_dioxide_emissions_per_capita.xlsx')
CO2s = pd.read_excel('indicator CDIAC carbon_dioxide_emissions_per_capita2.xlsx')

# %%
CO2_2007= pd.DataFrame(np.log(CO2[pd.notnull(CO2[2007])][2007]))
VEHICLES_2007= pd.DataFrame(np.log(VEHICLES[pd.notnull(VEHICLES[2007])][2007]))
ENERGY_2007= pd.DataFrame(np.log(ENERGY[pd.notnull(ENERGY["2007"])]["2007"]))
ENERGY_SUPPLY_2010= pd.DataFrame(np.log(ENERGY_SUPPLY[pd.notnull(ENERGY_SUPPLY[2010])][2010]))
CO2_2007 = CO2_2007.rename(columns={2007: 'CO2_2007'})
VEHICLES_2007 = VEHICLES_2007.rename(columns={2007: 'VEHICLES_2007'})
ENERGY_2007 = ENERGY_2007.rename(columns={"2007": 'ENERGY_2007'})
ENERGY_SUPPLY_2010 = ENERGY_SUPPLY_2010.rename(columns={2010: 'ENERGY_SUPPLY_2010'})

df1 = pd.concat([CO2_2007,VEHICLES_2007,ENERGY_2007,ENERGY_SUPPLY_2010],axis=1, join='inner')

# %% [markdown]
# ##Teste de Correlação (OLS)

# %%
result1 = sm.formula.ols(formula="CO2_2007 ~ VEHICLES_2007 + ENERGY_2007 + ENERGY_SUPPLY_2010",data=df1).fit()
print (result.params)
result1.summary()
# Out:
# Intercept       -0.190949
# VEHICLES_2007    0.187730
# ENERGY_2007      0.483093
# dtype: float64
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ...
# Dep. Variable:               CO2_2007   R-squared:                       0.166
# Model:                            OLS   Adj. R-squared:                  0.126
# Method:                 Least Squares   F-statistic:                     4.110
# Date:                Sun, 29 Nov 2015   Prob (F-statistic):             0.0100
# Time:                        11:24:45   Log-Likelihood:                -123.28
# No. Observations:                  66   AIC:                             254.6
# Df Residuals:                      62   BIC:                             263.3
# Df Model:                           3
# ...
#                          coef    std err          t      P>|t|      [95.0% Conf. Int.]
# --------------------------------------------------------------------------------------
# ...

# %%
from pandas.stats.api import ols
ols(y=df1['CO2_2007'], x=df1[['VEHICLES_2007','ENERGY_2007','ENERGY_SUPPLY_2010']])
# Out:
# -------------------------Summary of Regression Analysis-------------------------
#
# Formula: Y ~ <VEHICLES_2007> + <ENERGY_2007> + <ENERGY_SUPPLY_2010>
#              + <intercept>
#
# Number of Observations:         66
# Number of Degrees of Freedom:   4
#
# R-squared:         0.1659
# Adj R-squared:     0.1255
#
# Rmse:              1.6164
#
# F-stat (3, 62):     4.1100, p-value:     0.0100
#
# Degrees of Freedom: model 3, resid 62
#
# -----------------------Summary of Estimated Coefficients------------------------
#       Variable       Coef    Std Err     t-stat    p-value    CI 2.5%   CI 97.5%
# --------------------------------------------------------------------------------
#  VEHICLES_2007     0.1965     0.1281       1.53     0.1301    -0.0546     0.4477
#    ENERGY_2007     0.4842     0.1479       3.27     0.0017     0.1944     0.7740
# ENERGY_SUPPLY_2010    -0.0444     0.1979      -0.22     0.8233    -0.4323     0.3436
# ...

# %% [markdown]
# ##Interpretação dos dados do teste de Correlação #1
#
# ###P-Value (P>|t|)
# A partir de uma análise direta do **p-value**, que indica o teste da hipótese nula de que o coef. é igual a zero, se conseiderarmos **alpha**(valor de significância estatística) como o padrão de **5%** (0.05) podemos considerar os valores de **ENERGY_SUPPLY_2010** e **VEHICLES_2007** estatísticamente irrelevantes.
#
# Para termos de análise, consideremos nosso **alpha = 0.15**, assim, na nova iteração, manteremos ambos **ENERGY_2007** e **VEHICLES_2007**

# %%
result = sm.formula.ols(formula="CO2_2007 ~ VEHICLES_2007 + ENERGY_2007",data=df1).fit()
print (result.params)
result.summary()
# Out:
# Intercept       -0.190949
# VEHICLES_2007    0.187730
# ENERGY_2007      0.483093
# dtype: float64
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ...
# Dep. Variable:               CO2_2007   R-squared:                       0.165
# Model:                            OLS   Adj. R-squared:                  0.139
# Method:                 Least Squares   F-statistic:                     6.234
# Date:                Mon, 30 Nov 2015   Prob (F-statistic):            0.00339
# Time:                        11:26:15   Log-Likelihood:                -123.31
# No. Observations:                  66   AIC:                             252.6
# Df Residuals:                      63   BIC:                             259.2
# Df Model:                           2
# ...
#                     coef    std err          t      P>|t|      [95.0% Conf. Int.]
# ---------------------------------------------------------------------------------
# ...

# %%
from pandas.stats.api import ols
ols(y=df1['CO2_2007'], x=df1[['VEHICLES_2007','ENERGY_2007']])
# Out:
# -------------------------Summary of Regression Analysis-------------------------
#
# Formula: Y ~ <VEHICLES_2007> + <ENERGY_2007> + <intercept>
#
# Number of Observations:         66
# Number of Degrees of Freedom:   3
#
# R-squared:         0.1652
# Adj R-squared:     0.1387
#
# Rmse:              1.6042
#
# F-stat (2, 63):     6.2338, p-value:     0.0034
#
# Degrees of Freedom: model 2, resid 63
#
# -----------------------Summary of Estimated Coefficients------------------------
#       Variable       Coef    Std Err     t-stat    p-value    CI 2.5%   CI 97.5%
# --------------------------------------------------------------------------------
#  VEHICLES_2007     0.1877     0.1210       1.55     0.1258    -0.0495     0.4249
#    ENERGY_2007     0.4831     0.1467       3.29     0.0016     0.1956     0.7705
#      intercept    -0.1909     0.5894      -0.32     0.7470    -1.3461     0.9642
# ---------------------------------End of Summary---------------------------------

# %%
from mpl_toolkits.mplot3d import Axes3D

X = df1[['ENERGY_2007', 'VEHICLES_2007']]
y = df1['CO2_2007']

## fit a OLS model with intercept on TV and Radio
X = sm.add_constant(X)
est = sm.OLS(y, X).fit()
## Create the 3d plot -- skip reading this
# grid for 3d plot
xx1, xx2 = np.meshgrid(np.linspace(df1.ENERGY_2007.min(), df1.ENERGY_2007.max(), 100), 
                       np.linspace(df1.VEHICLES_2007.min(), df1.VEHICLES_2007.max(), 100))
# plot the hyperplane by evaluating the parameters on the grid
Z = est.params[0] + est.params[1] * xx1 + est.params[2] * xx2

# create matplotlib 3d axes
fig = plt.figure(figsize=(12, 8))
ax = Axes3D(fig, azim=-115, elev=15)

# plot hyperplane
surf = ax.plot_surface(xx1, xx2, Z, cmap=plt.cm.RdBu_r, alpha=0.6, linewidth=0)

# plot data points - points over the HP are white, points below are black
resid = df1.CO2_2007 - est.predict(X)
ax.scatter(df1[resid >= 0].ENERGY_2007, df1[resid >= 0].VEHICLES_2007, df1[resid >= 0].CO2_2007, color='black', alpha=1.0, facecolor='white')
ax.scatter(df1[resid < 0].ENERGY_2007, df1[resid < 0].VEHICLES_2007, df1[resid < 0].CO2_2007, color='black', alpha=1.0)

# set axis labels
ax.set_xlabel('ENERGY_2007')
ax.set_ylabel('VEHICLES_2007')
ax.set_zlabel('CO2_2007')

# %%
result2 = sm.formula.ols(formula="CO2_2007 ~ ENERGY_2007",data=df1).fit()
print (result.params)
result2.summary()
# Out:
# Intercept       -0.190949
# VEHICLES_2007    0.187730
# ENERGY_2007      0.483093
# dtype: float64
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ...
# Dep. Variable:               CO2_2007   R-squared:                       0.133
# Model:                            OLS   Adj. R-squared:                  0.120
# Method:                 Least Squares   F-statistic:                     9.845
# Date:                Mon, 30 Nov 2015   Prob (F-statistic):            0.00257
# Time:                        11:28:18   Log-Likelihood:                -124.55
# No. Observations:                  66   AIC:                             253.1
# Df Residuals:                      64   BIC:                             257.5
# Df Model:                           1
# ...
#                   coef    std err          t      P>|t|      [95.0% Conf. Int.]
# -------------------------------------------------------------------------------
# ...

# %%
from pandas.stats.api import ols
ols(y=df1['CO2_2007'], x=df1['ENERGY_2007'])
# Out:
# -------------------------Summary of Regression Analysis-------------------------
#
# Formula: Y ~ <x> + <intercept>
#
# Number of Observations:         66
# Number of Degrees of Freedom:   2
#
# R-squared:         0.1333
# Adj R-squared:     0.1198
#
# Rmse:              1.6217
#
# F-stat (1, 64):     9.8448, p-value:     0.0026
#
# Degrees of Freedom: model 1, resid 64
#
# -----------------------Summary of Estimated Coefficients------------------------
#       Variable       Coef    Std Err     t-stat    p-value    CI 2.5%   CI 97.5%
# --------------------------------------------------------------------------------
#              x     0.4634     0.1477       3.14     0.0026     0.1739     0.7529
#      intercept     0.6699     0.2008       3.34     0.0014     0.2763     1.0634
# ---------------------------------End of Summary---------------------------------

# %%
X = df1['ENERGY_2007']
y = df1['CO2_2007']

## fit a OLS model with intercept on TV and Radio
X = sm.add_constant(X)
est = sm.OLS(y, X).fit()
# We pick 100 hundred points equally spaced from the min to the max
X_prime = np.linspace(X['ENERGY_2007'].min(), X['ENERGY_2007'].max(), 100)[:, np.newaxis]
X_prime = sm.add_constant(X_prime)  # add constant as we id before

# Now we calculate the predicted values
y_hat = est.predict(X_prime)

plt.scatter(df1.ENERGY_2007, y, alpha=0.3)  # Plot the raw data
plt.xlabel("ENERGY_2007")
plt.ylabel("CO2_2007")
plt.plot(X_prime[:, 1], y_hat, 'r', alpha=0.9)  # Add the regression line, colored in red

# %%
result4 = sm.formula.ols(formula="CO2_2007 ~ VEHICLES_2007",data=df1).fit()
print (result4.params)
result4.summary()
# Out:
# Intercept        0.037105
# VEHICLES_2007    0.153300
# dtype: float64
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ...
# Dep. Variable:               CO2_2007   R-squared:                       0.021
# Model:                            OLS   Adj. R-squared:                  0.006
# Method:                 Least Squares   F-statistic:                     1.401
# Date:                Mon, 30 Nov 2015   Prob (F-statistic):              0.241
# Time:                        16:22:19   Log-Likelihood:                -128.55
# No. Observations:                  66   AIC:                             261.1
# Df Residuals:                      64   BIC:                             265.5
# Df Model:                           1
# ...
#                     coef    std err          t      P>|t|      [95.0% Conf. Int.]
# ---------------------------------------------------------------------------------
# ...

# %%
from pandas.stats.api import ols
ols(y=df1['CO2_2007'], x=df1['VEHICLES_2007'])
# Out:
# -------------------------Summary of Regression Analysis-------------------------
#
# Formula: Y ~ <x> + <intercept>
#
# Number of Observations:         66
# Number of Degrees of Freedom:   2
#
# R-squared:         0.0214
# Adj R-squared:     0.0061
#
# Rmse:              1.7233
#
# F-stat (1, 64):     1.4011, p-value:     0.2409
#
# Degrees of Freedom: model 1, resid 64
#
# -----------------------Summary of Estimated Coefficients------------------------
#       Variable       Coef    Std Err     t-stat    p-value    CI 2.5%   CI 97.5%
# --------------------------------------------------------------------------------
#              x     0.1533     0.1295       1.18     0.2409    -0.1005     0.4071
#      intercept     0.0371     0.6287       0.06     0.9531    -1.1952     1.2694
# ---------------------------------End of Summary---------------------------------

# %%
X = df1['VEHICLES_2007']
y = df1['CO2_2007']

## fit a OLS model with intercept on TV and Radio
X = sm.add_constant(X)
est = sm.OLS(y, X).fit()
# We pick 100 hundred points equally spaced from the min to the max
X_prime = np.linspace(X['VEHICLES_2007'].min(), X['VEHICLES_2007'].max(), 100)[:, np.newaxis]
X_prime = sm.add_constant(X_prime)  # add constant as we id before

# Now we calculate the predicted values
y_hat = est.predict(X_prime)

plt.scatter(df1.VEHICLES_2007, y, color='green',alpha=0.3)  # Plot the raw data
plt.xlabel("VEHICLES_2007")
plt.ylabel("CO2_2007")
plt.plot(X_prime[:, 1], y_hat, 'r', alpha=0.9)  # Add the regression line, colored in red

# %% [markdown]
# ## Interpretação dos dados do teste de Correlação #2
#
# Após a análise dos P-Value e das conclusões sobre significancia estatística, deve-se analisar outros valores frutos da análise estatística.
#
# ### Ponto de intersecção com o eixo Y (Intercept)
# Não há muito sobre essa variável ela realmente indica o ponto de intersecção no eixo das ordenadas.
#
# ### R-Quadrado (R-Squared:)
# Também conhecido como coeficiente de determinação(coefficient of determination) o R-quadrado indica o quanto dos dados se aproximam da linha ajustada de regressão (fitted regression line).
#
# O R-quadrado representa a porcentagem da resposta da variação variável(x) do modelo linear, ou seja:
#
# $R^2=\frac{SQ_\text{exp}}{SQ_\text{tot}}=1-\frac{SQ_\text{res}}{SQ_\text{tot}}$
#
# Variando de 0% até 100%:
#
# >0% indica que o modelo não explica de forma alguma a variabilidade das respostas em torno de sua média.
#
# >100% indica qu eo modelo explica toda a variabilidade das respostas em torno da média.
#
# Contudo, o R-quadrado, não permite determinar se tealmente existe uma tendência, assim, um R-Quadrado alto não indica um modelo que se ajusta perfeitamente aos dados, assim como um baixo não indica que definitivamente não se adequa.
#
# >Com uma influência(R-quadrado) de somente **0.165**, ainda pode-se tirar conclusões importantes desses dados, independentemente da influência realtivamente baixa na correlação.
#
# ### R-Quadrado Ajustado (Adj. R-squared:)
# O R-quadrado ajustado (Adjusted R-squared) normaliza a variação do R-quadrado. Com uma presmissa simples,
#
# >Quando se aumenta o número de variáveis que causam impacto na correlação, seu R-quadrado aumenta por que sua capacidade predição melhorou? ou somente porque aumentou o número de variáveis?
#
# Então o R-quadrado ajustado trabalha aumentando o seu valor caso o número de variáveis aumente e R-quadrado aumente mais do que valor esperado, por outro lado dimunui se o valor de R-quardrado aumentar menos do que o valor esperado.
#
# >Uma valor de R-quadrado igual a **0.139** indica que a adição de uma segunda variável ao conjunto das variáveis preditivas implicou em um aumento menor do que o esperado para o modelo. Uma vez que **0.139** < **0.165**.
#
# ### Teste-F (F-statistic:)
# Também conhecido como estatística-F, consiste em um teste que diferentemente do do teste-t (estatística-t) pode prever a significância do modelo para mais de uma variável. Contudo, a estatística-F não trabalha com as variáveis preditoras, ou seja, y (**CO2_2007**), assim assume um modelo que só possui intercepto.
#
# O teste-F assume como hipóteses:
#
# >Hipótese nula: O modelo que somente possui intercepto é igual ao modelo analisado.
#
# >Hipótese alternativa: O ajuste do modelo que somente possui intercepto é significantemente reduzido quando comparado com o modelo analisado.
#
# O que indica a significância dos dados analisados, ou seja, mesmo com fatores que indicam que seu modelo tem um bom ajuste, o **Teste-F comparado ao seu P-value** indica a significancia do modelo, descrita na variável **(Prob (F-statistic):)** no caso igual a **0.00339**. Portanto, mesmo com a significância de 5% ainda seria significativo, demonstrando um fator de não-aleatoriedade do modelo.
#
# ### Log-Likelihood
# O log-likelihood é a expressão maximizada para determinar os valores ideais dos coeficientes estimados (β).
#
# Os valores de log-likelihood não podem ser usados isoladamente como índice de ajuste porque são uma função do tamanho amostral, mas podem ser usados para comparar o ajuste de diferentes coeficientes. Como o objetivo é maximizar o log-likelihood, um valor mais alto é melhor.
#
# >Analizando os dados, o log-likehood do teste #1 e do teste #2 estao muito próximos (-123.28 e -123.31 repectivamente), portanto esse nao seria uma bom parâmetro para escolher o melhor modelo de regressão entre as duas possibilidades.
#
# ### O Critério de Informação de Akaike (AIC:) & O Critério de Informação Bayesiano (BIC)
# Ambos o AIC quanto o BIC aumentam conforme SQE aumenta, assim uma vez que o SQE tende a diminuir conforme aumenta-se o número de variáveis analisadas no modelo, esses valores ficam menores. Assim deve-se encontrar um balanço entre o aumento no número de variáveis e o valor de AIC e BIC.
#
# Existe um universo a ser explorado por trás destas duas variáveis. Contudo, somente um breve resumo foi apresentado, já que este não é o intuito deste documento, mais informações em:
#
# https://en.wikipedia.org/wiki/Akaike_information_criterion
#
# https://en.wikipedia.org/wiki/Bayesian_information_criterion
#
#
# ### Erro Padrão (std err)
# Também conhecido como Erro padrão da regressão, o Erro padraõ indica o quão errada está seu modelo de regressão. Valores menores associados ao Erro Padrão indicam que seus dados estão mais proximos da linha ajustada, dados na unidade das variáveis.
#
# Diferentemente do R-Quadrado, o Erro padrão pode ser usado como um excelente estimador para seus dados já que ele indica que 95% dos dados está a uma distância de mais ou menos duas vezes o erro padrão de sua linha ajustada.
#
# >Para a regressão analisada **0.121** para **VEHICLES_2007** e **0.147** para **ENERGY_2007**. Indicam a distância de 95% dos dados no modelo de regressão.
#
# ### Coeficientes de Correlação (Coef.)
# Representa a mudança média na resposta da variável para cada unidade do preditor(**CO2_2007**). Esse fator demonstra o quanto cada uma das variáveis está influenciando no sistema.
#
# >Observe que mais uma vez a exclusão da variável **ENERGY_SUPPLY_2010** foi apoiada, já que seu coef. de correlação. era igual a **-0.044378** o que indica que estava influênciando negativamente no modelo de correlação.
#
# ### T-statistic(t)
# Usa-se o teste t para testar a hipótese nula de que o coeficiente de uma determinada variável de previsão é zero, o que implica que um determinado indicador não tem qualquer efeito sobre a variável resposta. A hipótese alternativa é que o preditor contribua para a resposta. Em testes, defini-se um limiar alfa, e se p-value for menor que alfa rejeitamos a hipótese nula. O teste t geralmente nos permite avaliar a importância de diferentes fatores preditores, assumindo que os resíduos do modelo são normalmente distribuídos cerca do zero. Se os resíduos não se comportam desta maneira, então, isso sugere que exista alguma não-linearidade entre as variáveis, e que os seus testes-t não devem ser utilizados para avaliar a importância de preditores individuais. Além disso, pode ser melhor para tentar modificar o modelo, de modo que os resíduos tendam a agrupar normalmente cerca de zero.
#
# ### [95.0% Conf. Int.]
# Os valores inferior e superior do intervalo de confiança de 95%
#
# ### Skewness e Kurtosis
#
# Skewness e Kurtosis referem-se a forma da distribuição normal. Skewness é uma medida da distribuição de uma assimetria , Kurtosis é uma medida de sua curvatura.
# Para ser uma distribuição normal perfeita, tanto o Skewness quanto Kurtosis devem ser iguais a 0 ou, alternativamente, Skewness deve ser igual a 0 e o "regular run-of-the-mill kurtosis" seja igual a 3.
#
# >De novo, os valores do teste #1 e do teste #2 sao muito parecidos. Para o teste #1 o S= -1.347 e o K = 7.011, e para o teste #2 o S= -1.360e o K= 7.085. Além desses valores não conseguirem indicar qual o melhor modelo, nao segue os padros de uma normal, o que é um indicador de que o H0 deve ser rejeitado.
#
# ### Omnibus Test e Prob(Omnibus)
#
# O teste de Omnibus usa Skewness e Kurtosis para testar a hipótese nula de que a distribuição é normal. Neste caso, nós estamos olhando para a distribuição do residual. Se obtivermos um valor muito pequeno para Prob(Omnibus), então os resíduos não são normalmente distribuídos cerca de zero.
#
# > Os testes #1 e #2 possuem valores para o teste Omnibus muito próximos (**28.196 e 28.604 respectivamente**), o que mostra que esse não seria um bom parâmetro para escolher o melhor modelo de regressão entre os testes. Além disso, em ambos os casos a **Prob(Omnibus) foi igual a 0, isso sugere que os resíduos não estão distribuidos sugundo uma normal o que mostra que uma suposição feita em relação ao erro anteriormente estava errada, ou seja, é um indicador de que a hipotese nula (de que a distribuição dos erros é normal) deve ser rejeitada. Portanto, as inferências estatísticas devem ser rejeitadas**
#
# ### Durbin-Watson
#
# O teste Durbin-Watson verifica a existência de autocorrelação olhando os resíduos separados por algum desfasamento.
# Valores maiores que dois sugerem uma correlação negativa e valores menores que um sugerem correlação positiva.
#
# >Analizando os dados, o Durbin-Watson do teste #1 e do teste #2 são iguais (**2.120 para ambos**), portanto esse também nao seria uma bom parâmetro para escolher o melhor modelo de regressão entre as duas possibilidades. Porém é bom notar que ambos os modelos possuem valores maiores que dois, **o que sugere uma correlação negativa entre os erros em ambos os casos, uma suposição feita anteriormente**
#
# ### Jarque-Bera Test
#
# O teste Jarque-Bera é outro teste que considera skewness e kurtosis. A hipótese nula é que a distribuição é normal.
#
# ### Condition Number (Cond. No.)
#
# O número de condição mede a sensibilidade de saída de uma função para a sua entrada. Quando duas variáveis de previsão estão altamente correlacionados , que é chamado de multicolinearidade , os coeficientes ou fatores dessas variáveis de previsão podem flutuar de forma irregular para pequenas alterações nos dados , ou nos modelo. O ideal é que modelos similares devem ser semelhantes , ou seja , tenham coeficientes aproximadamente iguais. Multicolinearidade podem produzir resultados imprecisos.
#
# Se o número de condição for maior do que trinta a regressão pode ter multicolinearidade.
#
# >No teste #1 o número condicional deu 15.4 enquanto no teste #2 o número condicional deu 15. Mesmo sendo números muito próximos o do teste #2 foi menor que o do #1 mostrando que no segundo os dados tem "menos multicolinearidade".

# %%
from ipy_table import *
Corr = [['Arranjo','R-Quad.','R-Quad.Ajust','Prob.Teste-F','Prob.Omnibus','Skew','Kurtosis'],['E/V/ES',0.166,0.126,0.0100,0.000,-1.347,7.011],['E/V',0.165,0.139,0.00339,0.000,-1.360,7.085],['E',0.133,0.120,0.00257,0.000,-1.542,7.276],['V',0.021,0.006,0.241,0.001,-0.956,4.548],['V/ES',0.022,-0.009,0.503,0.001,-0.957,4.532],['E/ES',0.134,0.107,0.0107,0.000,-1.541,7.340]]
make_table(Corr)
apply_theme('basic')
set_global_style(float_format='%0.3E')
set_row_style(2,color='Red')
# Out:
# <table border="1" cellpadding="3" cellspacing="0"  style="border:1px solid black;border-collapse:collapse;"><tr><td  style="background-color:LightGray;"><b>Arranjo</b></td><td  style="background-color:LightGray;"><b>R-Quad.</b></td><td  style="background-color:LightGray;"><b>R-Quad.Ajust</b></td><td  style="background-color:LightGray;"><b>Prob.Teste-F</b></td><td  style="background-color:LightGray;"><b>Prob.Omnibus</b></td><td  style="background-color:LightGray;"><b>Skew</b></td><td  style="background-color:LightGray;"><b>Kurtosis</b></td></tr><tr><td  style="background-color:Ivory;">E/V/ES</td><td  style="background-color:Ivory;">0.166</td><td  style="background-color:Ivory;">0.126</td><td  style="background-color:Ivory;">0.01</td><td  style="background-color:Ivory;">0.0</td><td  style="background-color:Ivory;">-1.347</td><td  style="background-color:Ivory;">7.011</td></tr><tr><td  style="background-color:Red;">E/V</td><td  style="background-color:Red;">0.165</td><td  style="backgro
# ...

# %% [markdown]
# ###Conclusão Parcial:
# >Mesmo com os parâmetros próximos dos valores do modelo **E**,o modelo **E/V** destaca-se no R-quadrado, perdendo ligeiramente no fator F-Statistic. Mesmo assim, consideramos o modelo **E/V** superior.Uma vez que independentemente da ligeira discrepância ambos os valores estão contemplados em um **alpha**=0.05 o que demonstra a significância de ambos os modelos de regressão;

# %% [markdown]
# ##Análise da Influência das variáveis
# Percebemos após a análise dos dados anteriores que qualquer inferências estatística deve ser rejeitada, já que as hipóteses assumidas inicialmente são inválidas.
#
# Durante a análise da influência de cada variável perebe-se que exist um out-lier que está causando um aumento significativo no resíduo normal quadrado. Formulamos a hipótese de que o  [Lesoto](https://en.wikipedia.org/wiki/Lesotho) (**113**-No gráfico abaixo) poderia estar atrapalhando a produtividade do modelo.

# %%
fig, ax = plt.subplots(figsize=(8,6))
fig = sm.graphics.plot_leverage_resid2(result, ax=ax)

# %% [markdown]
# Novamente o Lesoto mostra-se mais uma vez um out-lier e aparentemente está causando problemas no modelo.

# %%
fix, ax = plt.subplots(figsize=(12,14))
fig = sm.graphics.plot_partregress("CO2_2007", "VEHICLES_2007", ["ENERGY_2007"], data=df1, ax=ax)

# %%
CO2_2007s = pd.DataFrame(np.log(CO2s[pd.notnull(CO2s[2007])][2007]))
CO2_2007s = CO2_2007s.rename(columns={2007: 'CO2_2007s'})

df3 = pd.concat([CO2_2007s,VEHICLES_2007,ENERGY_2007,ENERGY_SUPPLY_2010],axis=1, join='inner')

result3 = sm.formula.ols(formula="CO2_2007s ~ VEHICLES_2007 + ENERGY_2007",data=df3).fit()
print (result3.params)
result3.summary()
# Out:
# Intercept       -0.003471
# VEHICLES_2007    0.167939
# ENERGY_2007      0.558329
# dtype: float64
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ...
# Dep. Variable:              CO2_2007s   R-squared:                       0.261
# Model:                            OLS   Adj. R-squared:                  0.237
# Method:                 Least Squares   F-statistic:                     10.94
# Date:                Mon, 30 Nov 2015   Prob (F-statistic):           8.55e-05
# Time:                        15:43:00   Log-Likelihood:                -110.16
# No. Observations:                  65   AIC:                             226.3
# Df Residuals:                      62   BIC:                             232.8
# Df Model:                           2
# ...
#                     coef    std err          t      P>|t|      [95.0% Conf. Int.]
# ---------------------------------------------------------------------------------
# ...

# %%
from mpl_toolkits.mplot3d import Axes3D

X = df3[['ENERGY_2007', 'VEHICLES_2007']]
y = df3['CO2_2007s']

## fit a OLS model with intercept on TV and Radio
X = sm.add_constant(X)
est = sm.OLS(y, X).fit()
## Create the 3d plot -- skip reading this
# grid for 3d plot
xx1, xx2 = np.meshgrid(np.linspace(df3.ENERGY_2007.min(), df3.ENERGY_2007.max(), 100), 
                       np.linspace(df3.VEHICLES_2007.min(), df3.VEHICLES_2007.max(), 100))
# plot the hyperplane by evaluating the parameters on the grid
Z = est.params[0] + est.params[1] * xx1 + est.params[2] * xx2

# create matplotlib 3d axes
fig = plt.figure(figsize=(12, 8))
ax = Axes3D(fig, azim=-115, elev=15)

# plot hyperplane
surf = ax.plot_surface(xx1, xx2, Z, cmap=plt.cm.RdBu_r, alpha=0.6, linewidth=0)

# plot data points - points over the HP are white, points below are black
resid = df3.CO2_2007s - est.predict(X)
ax.scatter(df3[resid >= 0].ENERGY_2007, df3[resid >= 0].VEHICLES_2007, df3[resid >= 0].CO2_2007s, color='black', alpha=1.0, facecolor='white')
ax.scatter(df3[resid < 0].ENERGY_2007, df3[resid < 0].VEHICLES_2007, df3[resid < 0].CO2_2007s, color='black', alpha=1.0)

# set axis labels
ax.set_xlabel('ENERGY_2007')
ax.set_ylabel('VEHICLES_2007')
ax.set_zlabel('CO2_2007s')

# %% [markdown]
# ###Análise Parcial:
# ####Percepções sobre a variação causada pela ausência do 113 - Losoto
# Como pode-se perceber, ao retirar o outliner,  os parametros melhoram significamente. O Prob(Omnibus) aumenta,  e o Skew e o Kurtosis se aproximam do 0. Isso mostra que os erros devem seguir um modelo normal, algo que nao refuta a hipotes H0

# %%
result5 = sm.formula.ols(formula="CO2_2007s ~ ENERGY_2007",data=df3).fit()
print (result5.params)
result5.summary()
# Out:
# Intercept      0.767729
# ENERGY_2007    0.541666
# dtype: float64
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ...
# Dep. Variable:              CO2_2007s   R-squared:                       0.228
# Model:                            OLS   Adj. R-squared:                  0.216
# Method:                 Least Squares   F-statistic:                     18.65
# Date:                Mon, 30 Nov 2015   Prob (F-statistic):           5.68e-05
# Time:                        16:28:19   Log-Likelihood:                -111.55
# No. Observations:                  65   AIC:                             227.1
# Df Residuals:                      63   BIC:                             231.5
# Df Model:                           1
# ...
#                   coef    std err          t      P>|t|      [95.0% Conf. Int.]
# -------------------------------------------------------------------------------
# ...

# %%
X = df3['ENERGY_2007']
y = df3['CO2_2007s']

## fit a OLS model with intercept on TV and Radio
X = sm.add_constant(X)
est = sm.OLS(y, X).fit()
# We pick 100 hundred points equally spaced from the min to the max
X_prime = np.linspace(X['ENERGY_2007'].min(), X['ENERGY_2007'].max(), 100)[:, np.newaxis]
X_prime = sm.add_constant(X_prime)  # add constant as we id before

# Now we calculate the predicted values
y_hat = est.predict(X_prime)

plt.scatter(df3.ENERGY_2007, y, color='magenta',alpha=0.3)  # Plot the raw data
plt.xlabel("VEHICLES_2007")
plt.ylabel("CO2_2007s")
plt.plot(X_prime[:, 1], y_hat, 'r', alpha=0.9)  # Add the regression line, colored in red

# %%
from ipy_table import *
Corr = [['Arranjo','R-Quad.','R-Quad.Ajust','Prob.Teste-F','Prob.Omnibus','Skew','Kurtosis'],['E/V/ES',0.166,0.126,0.0100,0.000,-1.347,7.011],['E/V',0.165,0.139,0.00339,0.000,-1.360,7.085],['E/V - Sem Lesoto',0.261,0.237,8.55e-05,0.405,-0.372,2.967],['E',0.133,0.120,0.00257,0.000,-1.542,7.276],['E - Sem Lesoto',0.228,0.216,5.68e-05,0.034,-0.671,3.616],['V',0.021,0.006,0.241,0.001,-0.956,4.548],['V/ES',0.022,-0.009,0.503,0.001,-0.957,4.532],['E/ES',0.134,0.107,0.0107,0.000,-1.541,7.340]]
make_table(Corr)
apply_theme('basic')
set_global_style(float_format='%0.3E')
set_row_style(2,color='Red')
set_row_style(3,color='Blue')
# Out:
# <table border="1" cellpadding="3" cellspacing="0"  style="border:1px solid black;border-collapse:collapse;"><tr><td  style="background-color:LightGray;"><b>Arranjo</b></td><td  style="background-color:LightGray;"><b>R-Quad.</b></td><td  style="background-color:LightGray;"><b>R-Quad.Ajust</b></td><td  style="background-color:LightGray;"><b>Prob.Teste-F</b></td><td  style="background-color:LightGray;"><b>Prob.Omnibus</b></td><td  style="background-color:LightGray;"><b>Skew</b></td><td  style="background-color:LightGray;"><b>Kurtosis</b></td></tr><tr><td  style="background-color:Ivory;">E/V/ES</td><td  style="background-color:Ivory;">0.166</td><td  style="background-color:Ivory;">0.126</td><td  style="background-color:Ivory;">0.01</td><td  style="background-color:Ivory;">0.0</td><td  style="background-color:Ivory;">-1.347</td><td  style="background-color:Ivory;">7.011</td></tr><tr><td  style="background-color:Red;">E/V</td><td  style="background-color:Red;">0.165</td><td  style="backgro
# ...

# %% [markdown]
# ##Conclusão
# ###Modelos desconsiderados:
# >Mesmo aparentando alguma relação entre os dados, desconsideramos todo e qualquer modelo que contemplasse a variável **ENERGY_SUPPLY_2010**, uma vez que diretamente ao analisar os dados de **p-value**, como dito anteriormente, percebe-se que não possui valor de significância no modelo.
#
# >Alem disso, apos analisar a influencia das variaveis, pudemos perceber que havia um pais que era um grande out-liner, o que podia estar influenciando nos nosso parametros,como por exemplos o fato de que os erros nao seguiam uma distribuicao normal, uma suposicao feita no comeco da analise. Por isso analisamos de novo  os dados, porem agora, sem esse outliner, o que melhorou muito os paramentros
#
# ###Melhor modelo de regressão:
# Após analisar cada parâmetro podemos concluir que o modelo com os melhores parâmetros seria o **E/V-Sem Lesoto** ,composto por **ENERGY_2007** e **VEHICLES_2007** sem o pais outliner.O modelo possui os melhores parâmetros de R-quadrado, R-quadrado Ajustado, Prob.Teste-F, Prob.Omnibus, Skew e Kurtosis.
